# %%
# Install Library
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# Import Library
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd
import csv

# %%
# Mengambil 3000 Review Aplikasi Depo Bangunan
scrapreview = reviews_all(
    'com.membercare',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count = 30000
)

# %%
# Simpan Data Review ke CSV
with open('review.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['content'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
# Membuat Dataframe dari hasil Scrap Review
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  17b15a0c-dec9-4f1e-ace5-8d2eb0681f91       Bumi Damai
# 1  5727983b-0cd7-4edc-bd0d-7b0e91ac4ac2      Eri Katamso
# 2  51ac1d7f-b21e-4e5f-b9ff-00b12a1a9b70    Ahsanul Ahsan
# 3  2237f16f-4324-4046-b50e-03674a6327a5  Pengguna Google
# 4  0cd8a1cb-7c55-4b36-b4c8-6be9ee151b48        irzal A.S
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Setelah update tidak bisa menu pencarian. Tlg ...      1              0
# 1  Mau login lagi kok susah... sudah masukan OTP ...      1              0
# 2  Setelah diupdate, pencarian bahan bangunan sem...      1              2
# 3  Terimakasih depo bangunan sudah mempermudah ka...      5              7
# 4  Aplikasi ngebug. Filter berdasarkan brand tida...      1              7
#
#   reviewCreatedVersion                  at  \
# 0               2.9.95 2025-01-06 23:46:37
# 1               2.9.95 2024-12-22 06:57:24
# 2               2.9.86 2024-02-11 02:22:19
# 3                  1.3 2019-09-07 16:14:11
# 4               1.3.22 2020-06-07 07:14:51
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Kami memohon maaf yang sebesar besarnya atas k... 2020-06-18 01:33:38
#
#   appVersion
# 0     2.9.95
# 1     2.9.95
# 2     2.9.86
# 3        1.3
# 4     1.3.22
